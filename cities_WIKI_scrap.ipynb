# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import re

# %%
url = "https://en.wikipedia.org/wiki/Berlin"

# %%
response = requests.get(url)
response.status_code # 200 status code = OK
# Out:
# 200

# %%
soup = BeautifulSoup(response.content, "html.parser")
soup
# Out:
# <!DOCTYPE html>
#
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-enabled vector-feature-main-menu-pinned-disabled vector-feature-limited-width-enabled vector-feature-limited-width-content-enabled vector-feature-zebra-design-disabled" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Berlin - Wikipedia</title>
# ...

# %%
soup.select("#firstHeading")
# Out:
# [<h1 class="firstHeading mw-first-heading" id="firstHeading"><span class="mw-page-title-main">Berlin</span></h1>]

# %%
soup.select("#firstHeading")[0].get_text()
# Out:
# 'Berlin'

# %%
soup.select('.infobox-data')[0].get_text()
# Out:
# 'Germany'

# %%
def wiki(cities):
    
  list_for_df = []


  for city in cities:
    url = f'https://en.wikipedia.org/wiki/{city}'

    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')

    response_dict = {}

    response_dict['city'] = soup.select(".firstHeading")[0].get_text()
    response_dict['country'] = soup.select(".infobox-data")[0].get_text()
    response_dict['latitude'] = soup.select(".latitude")[0].get_text()
    response_dict['longitude'] = soup.select(".longitude")[0].get_text()
    # not all of the wikipedia pages contain elevation(Hamburg)Hamburg
    if soup.select_one('.infobox-label:-soup-contains("Elevation")'):
      response_dict['elevation'] = soup.select_one('.infobox-label:-soup-contains("Elevation")').find_next(class_='infobox-data').get_text()
    else:
      response_dict['elevation'] = 0
    response_dict['website'] = soup.select_one('.infobox-label:-soup-contains("Website")').find_next(class_='infobox-data').get_text()
    if soup.select_one('th.infobox-header:-soup-contains("Population")'):
        response_dict['population'] = soup.select_one('th.infobox-header:-soup-contains("Population")').parent.find_next_sibling().find(text=re.compile(r'\d+'))
    else:
        response_dict['population'] = 0
   
    list_for_df.append(response_dict)


  cities_df = pd.DataFrame(list_for_df)

  return cities_df

# %%
list_of_cities = ['Berlin', 'Hamburg', 'London', 'Manchester', 'Barcelona']
wiki(list_of_cities)
# Out:
#          city         country    latitude   longitude      elevation  \
# 0      Berlin         Germany  52°31′12″N  13°24′18″E  34 m (112 ft)
# 1     Hamburg         Germany     53°33′N     10°00′E              0
# 2      London  United Kingdom  51°30′26″N    0°7′39″W   36 ft (11 m)
# 3  Manchester  United Kingdom  53°28′46″N   2°14′43″W  125 ft (38 m)
# 4   Barcelona           Spain  41°22′58″N  02°10′37″E   12 m (39 ft)
#
#               website population
# 0           berlin.de  3,850,809
# 1         hamburg.com  1,945,532
# 2  www.london.gov.uk   8,799,800
# 3   manchester.gov.uk    551,938
# 4  www.barcelona.cat   1,620,343

# %%
cities_df = pd.DataFrame(recreate_wiki(list_of_cities))
cities_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 cities_df = pd.DataFrame(recreate_wiki(list_of_cities))
#       2 cities_df
#
# NameError: name 'pd' is not defined

# %%
cities_df.to_csv('iss_cities')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 cities_df.to_csv('iss_cities')
#
# NameError: name 'cities_df' is not defined

# %%
#citites_loc = [(52.31, 13.24), (30.23, 40.2)]

#all_airports_df = pd.json_normalize(response.json()['items'])#pd.DataFrame()
#for loc in citites_loc:
#    lat, long = loc
#    all_airports_df = pd.concat([all_airports_df, retrive_aiport(lat, long)], ignore_index=True)

# %%
----------------------------------------MYYSQL

# %%
import os
from dotenv import load_dotenv

# %%
from pathlib import Path  # python3 only
env_path = Path('.') / 'env'
load_dotenv(dotenv_path=env_path)

# %%
import os 
SECRET_KEY_SQL = os.getenv('SQL_KEY')

# %%
import sqlalchemy

# %%
schema="sql_workshop"
host="YOUR"
user="root"
password=SECRET_KEY_SQL
port=3306
con = f'mysql+pymysql://{user}:{password}@{host}:{port}/{schema}'

# %%
df.to_sql('iss_population',
              if_exists='append', 
              con=con, 
              index=False)

# %%
NEW CONNECTION

# %%
import os
from dotenv import load_dotenv

# %%
from pathlib import Path  # python3 only
env_path = Path('.') / 'env'
load_dotenv(dotenv_path=env_path)
# Out:
# Python-dotenv could not parse statement starting at line 8
# Python-dotenv could not parse statement starting at line 11
# Python-dotenv could not parse statement starting at line 12
# True

# %%
AWS = os.getenv('AWS')

# %%
import sqlalchemy

# %%
schema="sql_workshop" # renamed from "iss_workshop"
host="YOUR"
user="admin"
password=AWS
port=3306
con = f'mysql+pymysql://{user}:{password}@{host}:{port}/{schema}'

# %%
import pandas as pd
import pymysql

# %%
df = pd.read_csv('iss_cities')

# %%
#If your CSV file is stored in a different directory, you need to provide the full path to the file. For example, if your CSV file is stored in the “data” directory of your Jupyter Notebook, you can load it by running the following command:
#df = pd.read_csv('data/mydata.csv')

# %%
df.to_sql('iss_population', 
              if_exists='append', 
              con=con, 
              index=False)
